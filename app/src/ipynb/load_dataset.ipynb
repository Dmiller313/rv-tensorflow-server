# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import cv2
import random

DATADIR = "./data"
CATEGORIES = ["coffee","cardboard","bottle"]

training_data = []

def create_training_data():
    for category in CATEGORIES:
        path = os.path.join(DATADIR, category) #path to data directory
        class_num = CATEGORIES.index(category) #assign classification int
        for img in os.listdir(path):
            joinPath = os.path.join(path,img)
            if(img != ".ipynb_checkpoints"):
                try:
                    print(joinPath)
                    img_array = cv2.imread(joinPath, cv2.IMREAD_GRAYSCALE) #create array, make all images grayscale
                    new_array = cv2.resize(img_array, (128,128))
                    #do not resize image LxW, all images are 512x512
                    training_data.append([new_array, class_num])
                except Exception as e:
                    pass #this is bad code

create_training_data()
# Out:
# ./data/coffee/coffee (62).png
# ./data/coffee/coffee (40).png
# ./data/coffee/coffee (61).png
# ./data/coffee/coffee (3).png
# ./data/coffee/coffee (27).png
# ./data/coffee/coffee (21).png
# ./data/coffee/coffee (58).png
# ./data/coffee/coffee (23).png
# ./data/coffee/coffee (45).png
# ./data/coffee/coffee (16).png
# ./data/coffee/coffee (34).png
# ./data/coffee/coffee (73).png
# ./data/coffee/coffee (74).png
# ./data/coffee/coffee (56).png
# ./data/coffee/coffee (78).png
# ./data/coffee/coffee (17).png
# ./data/coffee/coffee (28).png
# ./data/coffee/coffee (76).png
# ./data/coffee/coffee (5).png
# ./data/coffee/coffee (42).png
# ./data/coffee/coffee (54).png
# ./data/coffee/coffee (6).png
# ./data/coffee/coffee (30).png
# ./data/coffee/coffee (65).png
# ./data/coffee/coffee (66).png
# ./data/coffee/coffee (51).png
# ./data/coffee/coffee (18).png
# ./data/coffee/coffee (69).png
# ./data/coffee/coffee (20).png
# ./data/coffee/coffee (72).png
# ./data/coffee/coffee (79).png
# ./data/coffee/coffee (11).PNG
# ./data/coffee/coffee (25).png
# ./data/coffee/coffee (1).png
# ./data/coffee/coffee (41).png
# ./data/coffee/coffee (70).png
# ./data/coffee/coffee (75).png
# ./data/coffee/coffee (38).png
# ./data/coffee/coffee (10).png
# ./data/coffee/coffee (2).png
# ./data/coffee/coffee (68).png
# ./data/coffee/coffee (71).png
# ./data/coffee/coffee (77).png
# ./data/coffee/coffee (32).png
# ./data/coffee/coffee (13).png
# ./data/coffee/coffee (22).png
# ./data/coffee/coffee (60).png
# ./data/coffee/coffee (31).png
# ./data/coffee/coffee (43).png
# ./data/coffee/coffee (59).png
# ./data/coffee/coffee (37).png
# ./data/coffee/coffee (48).png
# ./data/coffee/coffee (19).png
# ./data/coffee/coffee (64).png
# ./data/coffee/coffee (44).png
# ./data/coffee/coffee (53).png
# ./data/coffee/coffee (12).png
# ./data/coffee/coffee (49).png
# ./data/coffee/coffee (35).png
# ./data/coffee/coffee (39).png
# ./data/coffee/coffee (63).png
# ./data/coffee/coffee (29).png
# ./data/coffee/coffee (55).png
# ./data/coffee/coffee (15).png
# ./data/bottle/bottle (55).png
# ./data/bottle/bottle (47).png
# ./data/bottle/bottle (5).png
# ./data/bottle/bottle (6).png
# ./data/bottle/bottle (33).png
# ./data/bottle/bottle (38).png
# ./data/bottle/bottle (3).png
# ./data/bottle/bottle (74).png
# ./data/bottle/bottle (26).png
# ./data/bottle/bottle (14).png
# ./data/bottle/bottle (83).png
# ./data/bottle/bottle (97).png
# ./data/bottle/bottle (22).png
# ./data/bottle/bottle (59).png
# ./data/bottle/bottle (9).png
# ./data/bottle/bottle (71).png
# ./data/bottle/bottle (35).png
# ./data/bottle/bottle (75).png
# ./data/bottle/bottle (70).png
# ./data/bottle/bottle (34).png
# ./data/bottle/bottle (2).png
# ./data/bottle/bottle (32).png
# ./data/bottle/bottle (57).png
# ./data/bottle/bottle (30).png
# ./data/bottle/bottle (100).png
# ./data/bottle/bottle (19).png
# ./data/bottle/bottle (102).png
# ./data/bottle/bottle (79).png
# ./data/bottle/bottle (72).png
# ./data/bottle/bottle (44).png
# ./data/bottle/bottle (63).png
# ./data/bottle/bottle (46).png
# ./data/bottle/bottle (24).png
# ./data/bottle/bottle (61).png
# ./data/bottle/bottle (18).png
# ./data/bottle/bottle (105).png
# ./data/bottle/bottle (45).png
# ./data/bottle/bottle (52).png
# ./data/bottle/bottle (64).png
# ./data/bottle/bottle (41).png
# ./data/bottle/bottle (62).png
# ./data/bottle/bottle (36).png
# ./data/bottle/bottle (73).png
# ./data/bottle/bottle (27).png
# ./data/bottle/bottle (11).png
# ./data/bottle/bottle (43).png
# ./data/bottle/bottle (104).png
# ./data/bottle/bottle (92).png
# ./data/bottle/bottle (40).png
# ./data/bottle/bottle (12).png
# ./data/bottle/bottle (16).png
# ./data/bottle/bottle (96).png
# ./data/bottle/bottle (107).png
# ./data/bottle/bottle (84).png
# ./data/bottle/bottle (106).png
# ./data/bottle/bottle (80).png
# ./data/bottle/bottle (94).png
# ./data/bottle/bottle (91).png
# ./data/bottle/bottle (15).png
# ./data/bottle/bottle (48).png
# ./data/bottle/bottle (23).png
# ./data/bottle/bottle (56).png
# ./data/bottle/bottle (85).png
# ./data/bottle/bottle (103).png
# ./data/bottle/bottle (86).png
# ./data/bottle/bottle (58).png

# %%
print(len(training_data)) #how many images do we have in the model?
# Out:
# 284

# %%
random.shuffle(training_data) #shuffle images so dataset does not skew

# %%
X = [] #featureset
y = [] #labels

for features, label in training_data:
    #print(label)
    X.append(features)
    y.append(label)
    
X = np.array(X).reshape(-1, 128, 128, 1)
y = np.array(y)

# %%
import pickle

pickle_out = open("X.pickle","wb")
pickle.dump(X, pickle_out)
pickle_out.close()

pickle_out = open("y.pickle","wb")
pickle.dump(y, pickle_out)
pickle_out.close()

# %%
X = pickle.load(open("X.pickle","rb"))
y = pickle.load(open("y.pickle","rb"))
